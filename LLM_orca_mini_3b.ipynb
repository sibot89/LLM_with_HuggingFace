# %% [markdown]
# <a href="https://colab.research.google.com/github/sibot89/LLM_with_HuggingFace/blob/main/LLM_orca_mini_3b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ctransformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 37.4 MB/s eta 0:00:00
# ...

# %%
from ctransformers import AutoModelForCausalLM

llm = AutoModelForCausalLM.from_pretrained("zoltanctoth/orca_mini_3B-GGUF",
                           model_file="orca-mini-3b.q4_0.gguf")

prompt = "The capital of Turkey is "

for word in llm(prompt, stream=True):
  print(word, end="", flush=True)

print()
# Out:
# ...
# Fetching 0 files: 0it [00:00, ?it/s]
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# 19-315 million USD in 2019, the latest data available.
# The GDP of Turkey is 83.6 billion USD in 2019, according to World Bank data.
